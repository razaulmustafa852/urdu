# %%
import numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# importing necessary libraries 
from sklearn import datasets 
from sklearn.metrics import confusion_matrix 
from sklearn.model_selection import train_test_split

# %%
# load dataset
#df = pd.read_csv("drData - Sheet1.csv")

#bba_2 = pd.read_csv("dashbed/BBA2CAT.csv")
#df = df.replace(np.nan, 0)

# %%
#df.columns

# %%
#df['Source'].unique()

# %%
#df.apply(lambda x: x.astype(str).str.upper())

# %%
#df.to_csv('drsummiya.csv')

# %%
df = pd.read_csv("drsummiya.csv")

# %%
df.columns
# Out:
# Index(['Age', 'Education', 'Gender', 'Location', 'Marital Status',
#        'Presence Psychiatric disorder', 'Stay', 'Treatment',
#        'Previous Attempts', 'Source', 'Expired'],
#       dtype='object')

# %%
df['Education'].unique()
# Out:
# array(['PRIMARY', 'MIDDLE', 'UNEDUCATED', 'ABOVE'], dtype=object)

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Marital Status', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Education", "Age")
ax.add_legend(title='')
ax.set_axis_labels("Education", "Age")
axes = ax.axes.flatten()
axes[0].set_title("Male")
axes[1].set_title("Female")
# Out:
# Text(0.5, 1, 'Female')

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Marital Status', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Age", "Source")
ax.add_legend(title='')
#ax.set_axis_labels("Education", "Age")
axes = ax.axes.flatten()
axes[0].set_title("Male")
axes[1].set_title("Female")
# Out:
# Text(0.5, 1, 'Female')

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Marital Status', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Previous Attempts", "Age")
ax.add_legend(title='')
#ax.set_axis_labels("Education", "Age")
axes = ax.axes.flatten()
axes[0].set_title("Male")
axes[1].set_title("Female")
# Out:
# Text(0.5, 1, 'Female')

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Marital Status', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Presence Psychiatric disorder", "Age")
ax.add_legend(title='')
#ax.set_axis_labels("Education", "Age")
axes = ax.axes.flatten()
axes[0].set_title("Male")
axes[1].set_title("Female")
# Out:
# Text(0.5, 1, 'Female')

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Marital Status', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Age", "Treatment")
ax.add_legend(title='')
#ax.set_axis_labels("Education", "Age")
axes = ax.axes.flatten()
axes[0].set_title("Male")
axes[1].set_title("Female")
# Out:
# Text(0.5, 1, 'Female')

# %%
ax = sns.FacetGrid(df, col="Gender", hue='Previous Attempts', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Presence Psychiatric disorder", "Age")
ax.add_legend()

# %%
ax = sns.FacetGrid(df, col="Location", hue='Previous Attempts', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Age", "Source")
ax.add_legend()

# %%
ax = sns.FacetGrid(df, col="Marital Status", hue='Previous Attempts', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Age", "Source")
ax.add_legend()

# %%
ax = sns.FacetGrid(df, col="Marital Status",  hue='Gender', height=4,  hue_kws={"marker": ['*','x']} )
ax.map(plt.scatter, "Education", "Source")
ax.add_legend()

# %%
Source of Taking Poison ML

CUSO4, ACID INtake strong, 

RAT, WHEAT Pills, Legislations, 


The study is undevopled.
